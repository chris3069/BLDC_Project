# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = np.linspace(0, (np.pi*2), 60)
y = 49+49*np.sin(x)

# %%
y_int = y.astype(int)

# %%
np.savetxt("test.csv", y_int, fmt="%i", delimiter= ",")

# %%
plt.plot(x,y)
plt.show()
